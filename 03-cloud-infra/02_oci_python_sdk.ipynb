# %% [markdown]
# # 3.2 OCI Python SDK> ☕ You have the OCI Foundations cert — now automate it with Python.---

# %%
# import oci# # # Uses ~/.oci/config by default (same as Java SDK)# config = oci.config.from_file()# # # Object Storage — like S3# object_storage = oci.object_storage.ObjectStorageClient(config)# namespace = object_storage.get_namespace().data# # # List buckets# compartment_id = config['tenancy']# buckets = object_storage.list_buckets(namespace, compartment_id).data# for b in buckets:#     print(f"  {b.name} (created: {b.time_created})")print("OCI SDK examples — uncomment with real OCI credentials")

# %%
# OCI Data Flow — managed Spark (like EMR)# # data_flow = oci.data_flow.DataFlowClient(config)# # # Submit a Spark application# run_details = oci.data_flow.models.CreateRunDetails(#     compartment_id=compartment_id,#     application_id='ocid1.dataflowapplication.oc1...',#     display_name='Healthcare ETL Run',#     arguments=['--date', '2024-01-15'],# )# # run = data_flow.create_run(run_details).data# print(f"Run ID: {run.id}, Status: {run.lifecycle_state}")print("OCI Data Flow example — your Oozie/EMR experience maps directly here")
